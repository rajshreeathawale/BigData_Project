# %% [markdown]
# <a href="https://colab.research.google.com/github/rajshreeathawale/BigData_Project/blob/main/MainProject.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Main Project(BigData)

# %%
import pandas as pd

# %%
df=pd.read_csv("World energy consumption.csv")
df.head(250)
# Out:
#     country  coal_consumption  coal_electricity  coal_production  \
# 0    ASEAN                NaN             71.03              NaN
# 1    ASEAN                NaN             80.02              NaN
# 2    ASEAN                NaN             87.16              NaN
# 3    ASEAN                NaN             98.51              NaN
# 4    ASEAN                NaN            111.62              NaN
# ..      ...               ...               ...              ...
# 245  Africa           963.730            194.63         1518.354
# 246  Africa           975.926            199.22         1514.537
# 247  Africa           934.422            205.16         1489.183
# 248  Africa          1017.048            219.97         1600.220
# 249  Africa          1119.162            229.76         1635.615
#
#      electricity_generation  fossil_fuel_consumption  gas_consumption  \
# 0                    368.65                      NaN              NaN
# ...

# %%
# Handle missing values
df.fillna(df.mean(), inplace=True)
# Out:
# <ipython-input-9-215a67fbbad9>:2: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.fillna(df.mean(), inplace=True)

# %%
df.describe()
# Out:
#        coal_consumption  coal_electricity  coal_production  \
# count      22012.000000      22012.000000     22012.000000
# mean        1880.502099        325.682578       969.427817
# std         2623.840287        606.565059      2986.846647
# min            0.000000          0.000000         0.000000
# 25%         1880.502099        205.160000         0.000000
# 50%         1880.502099        325.682578        25.485500
# 75%         1880.502099        325.682578       969.427817
# max        44858.121000      10190.710000     48490.000000
#
#        electricity_generation  fossil_fuel_consumption  gas_consumption  \
# count            22012.000000             22012.000000     22012.000000
# mean               769.798199              6403.128491      1478.561465
# std               1448.510213              7242.855029      1821.565678
# min                  0.000000                11.569000         0.000000
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 22012 entries, 0 to 22011
# Data columns (total 11 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   country                   22012 non-null  object
#  1   coal_consumption          22012 non-null  float64
#  2   coal_electricity          22012 non-null  float64
#  3   coal_production           22012 non-null  float64
#  4   electricity_generation    22012 non-null  float64
#  5   fossil_fuel_consumption   22012 non-null  float64
#  6   gas_consumption           22012 non-null  float64
#  7   gas_production            22012 non-null  float64
#  8   oil_consumption           22012 non-null  float64
#  9   oil_electricity           22012 non-null  float64
#  10  greenhouse_gas_emissions  22012 non-null  float64
# dtypes: float64(10), object(1)
# memory usage: 1.8+ MB

# %%
df.to_csv("C:\\Users\\Dell\\OneDrive\\Desktop\\World_EnergyConsumption.csv",index=False)
